# %% [markdown]
# ![Alt text](elephant.jpeg)

# %% [markdown]
# ![My Photo](elephant.jpeg)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("elephant.jpg")
plt.imshow(img)
plt.axis("off")  # hide axis
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
img = Image.open(r'C:\Users\sandh\OneDrive\Desktop\dump\elephant.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x360>
